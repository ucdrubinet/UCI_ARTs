# %% [markdown]
# CHANGELOG
#
# v0.5
# - for data_test_v2
#
# v0.0 6/16/23:
# - Dice score
#
# v0.1 6/19/23:
# - added in pearson correlation
#
# v0.2 6/19/23:
# - added hausdorff distance
# - added IoU
# - added AUC ROC
# - added AUC PR
#
# v0.3 6/24/23
# - added in access to jerry_losses.py

# %%
from jarvis.utils.general import gpus
gpus.autoselect()

import numpy as np, pandas as pd, tensorflow as tf, os
from tensorflow.keras import Input, Model,layers
from pathlib import Path
from jarvis.train import models, custom
from jarvis.utils.display import imshow
from scipy.spatial.distance import directed_hausdorff
from IPython.display import clear_output, HTML, Javascript, display

import sys  
sys.path.append('/home/jjlou/Jerry/jerry_packages')
from jerry_utils import restart_kernel, load_dataset
import jerry_losses, jerry_metrics
# Out:
# [ 2024-01-11 20:36:40 ] CUDA_VISIBLE_DEVICES automatically set to: 0
# /home/jjlou/.local/lib/python3.8/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.6.0 and strictly below 2.9.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
name = 'Attention_Unfrozen_EfficientNetV2L_v0.72'
root = '/home/jjlou/Jerry/wsi-arterio/arteriosclerotic_vessel_detection_and_fine_segmentation/Vessel_WallsLumen_Segmentation/data_test_v2'

custom_objects = {
    'dice_all': jerry_metrics.dice_metric(cls=1),
    'hausdorff_all': jerry_metrics.hausdorff_metric(cls=1),
    'focal_dice_like_loss_multiclass_weighted': jerry_losses.focal_dice_like_loss_multiclass_weighted
}

# %%
df_model_vl = pd.DataFrame(index=range(1))
df_model_vl['Hold mean'] = ''
df_model_vl['Hold std'] = ''
df_model_vl['Hold min'] = ''
df_model_vl['Hold 25%'] = ''
df_model_vl['Hold median'] = ''
df_model_vl['Hold 75%'] = ''
df_model_vl['Hold max'] = ''
df_model_vl['Hold pearson mean'] = ''
df_model_vl['Hold p mean'] = ''
df_model_vl['Hold hausdorff mean'] = ''
df_model_vl['Hold mIoU mean'] = ''
df_model_vl['Hold AUC-ROC mean'] = ''
df_model_vl['Hold AUC-PR mean'] = ''
df_model_vl['External mean'] = ''
df_model_vl['External std'] = ''
df_model_vl['External min'] = ''
df_model_vl['External 25%'] = ''
df_model_vl['External median'] = ''
df_model_vl['External 75%'] = ''
df_model_vl['External max'] = ''
df_model_vl['External pearson mean'] = ''
df_model_vl['External p mean'] = ''
df_model_vl['External pearson mean'] = ''
df_model_vl['External p mean'] = ''
df_model_vl['External hausdorff mean'] = ''
df_model_vl['External mIoU mean'] = ''
df_model_vl['External AUC-ROC mean'] = ''
df_model_vl['External AUC-PR mean'] = ''
    
df_model_v = pd.DataFrame(index=range(1))
df_model_v['Hold mean'] = ''
df_model_v['Hold std'] = ''
df_model_v['Hold min'] = ''
df_model_v['Hold 25%'] = ''
df_model_v['Hold median'] = ''
df_model_v['Hold 75%'] = ''
df_model_v['Hold max'] = ''
df_model_v['Hold pearson mean'] = ''
df_model_v['Hold p mean'] = ''
df_model_v['Hold hausdorff mean'] = ''
df_model_v['Hold mIoU mean'] = ''
df_model_v['Hold AUC-ROC mean'] = ''
df_model_v['Hold AUC-PR mean'] = ''
df_model_v['External mean'] = ''
df_model_v['External std'] = ''
df_model_v['External min'] = ''
df_model_v['External 25%'] = ''
df_model_v['External median'] = ''
df_model_v['External 75%'] = ''
df_model_v['External max'] = ''
df_model_v['External pearson mean'] = ''
df_model_v['External p mean'] = ''
df_model_v['External pearson mean'] = ''
df_model_v['External p mean'] = ''
df_model_v['External pearson mean'] = ''
df_model_v['External p mean'] = ''
df_model_v['External hausdorff mean'] = ''
df_model_v['External mIoU mean'] = ''
df_model_v['External AUC-ROC mean'] = ''
df_model_v['External AUC-PR mean'] = ''
    
df_model_l = pd.DataFrame(index=range(1))
df_model_l['Hold mean'] = ''
df_model_l['Hold std'] = ''
df_model_l['Hold min'] = ''
df_model_l['Hold 25%'] = ''
df_model_l['Hold median'] = ''
df_model_l['Hold 75%'] = ''
df_model_l['Hold max'] = ''
df_model_l['Hold pearson mean'] = ''
df_model_l['Hold p mean'] = ''
df_model_l['Hold hausdorff mean'] = ''
df_model_l['Hold mIoU mean'] = ''
df_model_l['Hold AUC-ROC mean'] = ''
df_model_l['Hold AUC-PR mean'] = ''
df_model_l['External mean'] = ''
df_model_l['External std'] = ''
df_model_l['External min'] = ''
df_model_l['External 25%'] = ''
df_model_l['External median'] = ''
df_model_l['External 75%'] = ''
df_model_l['External max'] = ''
df_model_l['External pearson mean'] = ''
df_model_l['External p mean'] = ''
df_model_l['External pearson mean'] = ''
df_model_l['External p mean'] = ''
df_model_l['External pearson mean'] = ''
df_model_l['External p mean'] = ''
df_model_l['External hausdorff mean'] = ''
df_model_l['External mIoU mean'] = ''
df_model_l['External AUC-ROC mean'] = ''
df_model_l['External AUC-PR mean'] = ''

# %%
load_path = f'{root}/models_raw/{name}'
model_path = f'{root}/models_raw/{name}.hdf5'
save_path = f'{root}/models_results'

df_hold_vl = pd.read_csv(f'{load_path}_hold_vl.csv')
df_external_vl = pd.read_csv(f'{load_path}_external_vl.csv')
df_hold_v = pd.read_csv(f'{load_path}_hold_v.csv')
df_external_v = pd.read_csv(f'{load_path}_external_v.csv')
df_hold_l = pd.read_csv(f'{load_path}_hold_l.csv')
df_external_l = pd.read_csv(f'{load_path}_external_l.csv')

i = 0

#Vessel and Lumen
#hold
df_model_vl['Hold mean'][i] = df_hold_vl['Hold dice score'].mean()
df_model_vl['Hold std'][i] = df_hold_vl['Hold dice score'].std()
df_model_vl['Hold min'][i] = df_hold_vl['Hold dice score'].min()
df_model_vl['Hold 25%'][i] = df_hold_vl['Hold dice score'].quantile(q=0.25)
df_model_vl['Hold median'][i] = df_hold_vl['Hold dice score'].median()
df_model_vl['Hold 75%'][i] = df_hold_vl['Hold dice score'].quantile(q=0.75)
df_model_vl['Hold max'][i] = df_hold_vl['Hold dice score'].max()
df_model_vl['Hold pearson mean'][i] = df_hold_vl['Hold pearson'].mean()
df_model_vl['Hold p mean'][i] = df_hold_vl['Hold p'].mean()
df_model_vl['Hold hausdorff mean'][i] = df_hold_vl['Hold hausdorff'].mean()
df_model_vl['Hold mIoU mean'][i] = df_hold_vl['Hold mIoU'].mean()
df_model_vl['Hold AUC-ROC mean'][i] = df_hold_vl['Hold ROC'].mean()
df_model_vl['Hold AUC-PR mean'][i] = df_hold_vl['Hold PR'].mean()

#external
df_model_vl['External mean'][i] = df_external_vl['External dice score'].mean()
df_model_vl['External std'][i] = df_external_vl['External dice score'].std()
df_model_vl['External min'][i] = df_external_vl['External dice score'].min()
df_model_vl['External 25%'][i] = df_external_vl['External dice score'].quantile(q=0.25)
df_model_vl['External median'][i] = df_external_vl['External dice score'].median()
df_model_vl['External 75%'][i] = df_external_vl['External dice score'].quantile(q=0.75)
df_model_vl['External max'][i] = df_external_vl['External dice score'].max()
df_model_vl['External pearson mean'][i] = df_external_vl['External pearson'].mean()
df_model_vl['External p mean'][i] = df_external_vl['External p'].mean()
df_model_vl['External hausdorff mean'][i] = df_external_vl['External hausdorff'].mean()
df_model_vl['External mIoU mean'][i] = df_external_vl['External mIoU'].mean()
df_model_vl['External AUC-ROC mean'][i] = df_external_vl['External ROC'].mean()
df_model_vl['External AUC-PR mean'][i] = df_external_vl['External PR'].mean()

#Vessel
#hold
df_model_v['Hold mean'][i] = df_hold_v['Hold dice score'].mean()
df_model_v['Hold std'][i] = df_hold_v['Hold dice score'].std()
df_model_v['Hold min'][i] = df_hold_v['Hold dice score'].min()
df_model_v['Hold 25%'][i] = df_hold_v['Hold dice score'].quantile(q=0.25)
df_model_v['Hold median'][i] = df_hold_v['Hold dice score'].median()
df_model_v['Hold 75%'][i] = df_hold_v['Hold dice score'].quantile(q=0.75)
df_model_v['Hold max'][i] = df_hold_v['Hold dice score'].max()
df_model_v['Hold pearson mean'][i] = df_hold_v['Hold pearson'].mean()
df_model_v['Hold p mean'][i] = df_hold_v['Hold p'].mean()
df_model_v['Hold hausdorff mean'][i] = df_hold_v['Hold hausdorff'].mean()
df_model_v['Hold mIoU mean'][i] = df_hold_v['Hold mIoU'].mean()
df_model_v['Hold AUC-ROC mean'][i] = df_hold_v['Hold ROC'].mean()
df_model_v['Hold AUC-PR mean'][i] = df_hold_v['Hold PR'].mean()

#external
df_model_v['External mean'][i] = df_external_v['External dice score'].mean()
df_model_v['External std'][i] = df_external_v['External dice score'].std()
df_model_v['External min'][i] = df_external_v['External dice score'].min()
df_model_v['External 25%'][i] = df_external_v['External dice score'].quantile(q=0.25)
df_model_v['External median'][i] = df_external_v['External dice score'].median()
df_model_v['External 75%'][i] = df_external_v['External dice score'].quantile(q=0.75)
df_model_v['External max'][i] = df_external_v['External dice score'].max()
df_model_v['External pearson mean'][i] = df_external_v['External pearson'].mean()
df_model_v['External p mean'][i] = df_external_v['External p'].mean()
df_model_v['External hausdorff mean'][i] = df_external_v['External hausdorff'].mean()
df_model_v['External mIoU mean'][i] = df_external_v['External mIoU'].mean()
df_model_v['External AUC-ROC mean'][i] = df_external_v['External ROC'].mean()
df_model_v['External AUC-PR mean'][i] = df_external_v['External PR'].mean()

#Lumen
#hold
df_model_l['Hold mean'][i] = df_hold_l['Hold dice score'].mean()
df_model_l['Hold std'][i] = df_hold_l['Hold dice score'].std()
df_model_l['Hold min'][i] = df_hold_l['Hold dice score'].min()
df_model_l['Hold 25%'][i] = df_hold_l['Hold dice score'].quantile(q=0.25)
df_model_l['Hold median'][i] = df_hold_l['Hold dice score'].median()
df_model_l['Hold 75%'][i] = df_hold_l['Hold dice score'].quantile(q=0.75)
df_model_l['Hold max'][i] = df_hold_l['Hold dice score'].max()
df_model_l['Hold pearson mean'][i] = df_hold_l['Hold pearson'].mean()
df_model_l['Hold p mean'][i] = df_hold_l['Hold p'].mean()
df_model_l['Hold hausdorff mean'][i] = df_hold_l['Hold hausdorff'].mean()
df_model_l['Hold mIoU mean'][i] = df_hold_l['Hold mIoU'].mean()
df_model_l['Hold AUC-ROC mean'][i] = df_hold_l['Hold ROC'].mean()
df_model_l['Hold AUC-PR mean'][i] = df_hold_l['Hold PR'].mean()

#external
df_model_l['External mean'][i] = df_external_l['External dice score'].mean()
df_model_l['External std'][i] = df_external_l['External dice score'].std()
df_model_l['External min'][i] = df_external_l['External dice score'].min()
df_model_l['External 25%'][i] = df_external_l['External dice score'].quantile(q=0.25)
df_model_l['External median'][i] = df_external_l['External dice score'].median()
df_model_l['External 75%'][i] = df_external_l['External dice score'].quantile(q=0.75)
df_model_l['External max'][i] = df_external_l['External dice score'].max()
df_model_l['External pearson mean'][i] = df_external_l['External pearson'].mean()
df_model_l['External p mean'][i] = df_external_l['External p'].mean()
df_model_l['External hausdorff mean'][i] = df_external_l['External hausdorff'].mean()
df_model_l['External mIoU mean'][i] = df_external_l['External mIoU'].mean()
df_model_l['External AUC-ROC mean'][i] = df_external_l['External ROC'].mean()
df_model_l['External AUC-PR mean'][i] = df_external_l['External PR'].mean()

# %%
# load model
model = tf.keras.models.load_model(model_path, custom_objects=custom_objects)

df_model_vl['Trainable Params'] = np.sum([np.prod(v.get_shape()) for v in model.trainable_weights])
df_model_v['Trainable Params'] = np.sum([np.prod(v.get_shape()) for v in model.trainable_weights])
df_model_l['Trainable Params'] = np.sum([np.prod(v.get_shape()) for v in model.trainable_weights])
    
df_model_vl.to_csv(f'{save_path}/{name}_vl.csv')
df_model_v.to_csv(f'{save_path}/{name}_v.csv')
df_model_l.to_csv(f'{save_path}/{name}_l.csv')
